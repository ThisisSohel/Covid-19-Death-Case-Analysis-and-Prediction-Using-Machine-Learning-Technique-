# %%
from pydataset import data
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from pylab import rcParams 
from sklearn import preprocessing
print('hello')
# Out:
# hello

# %%
data = pd.read_csv("covid_dataset.csv")

# label_encoder object using
label_encoder = preprocessing.LabelEncoder()
data['Day']= label_encoder.fit_transform(data['Day']) 
print(data.head(100))
# Out:
#     Day  Lab Test  Confirmed case  Death Case
# 0     0       434               9           2
# 1     1       367              18           1
# 2     2       468              35           3
# 3     3       679              41           5
# 4     4       981              54           3
# 5     5       905             112           1
# 6     6      1184              94           6
# 7     7       954              58           3
# 8     8      1340             139           4
# 9     9      1570             182           5
# 10   10      1905             209           7
# 11   11      1740             219           4
# 12   12      2019             341          10
# 13   13      2190             266          15
# 14   14      2114             306           9
# 15   15      2634             312           7
# 16   16      2779             492          10
# 17   17      2974             434           9
# 18   18      3096             390          10
# ...

# %%
data.plot(kind= 'scatter', x='Confirmed case', y='Death Case')
plt.show()

# %%
x = data[['Lab Test', 'Confirmed case']]
y = data['Death Case']

# %%
#test train Split
from sklearn.model_selection import ShuffleSplit
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)
data = ShuffleSplit(n_splits = 10, test_size=0.2, random_state =0)

# %%
L_reg = LinearRegression()
L_reg.fit(x_train.values, y_train.values)
# Out:
# LinearRegression()

# %%
predict = L_reg.predict(x_test.values)
#plt.plot(x_test, predict, label = 'Linear Regression', color = 'b')
#plt.scatter(x_test, y_test, label = 'The test Data', color = 'g', alpha = .7)
#plt.legend()
#plt.show()

# %%
x_test
# Out:
#      Lab Test  Confirmed case
# 581     13072             154
# 412     18294            1504
# 483     30980            9369
# 409     16855            1272
# 9        1570             182
# 270     15229            1235
# 254     16828            1799
# 512     27921            3948
# 562     18812             339
# 88      17875            3775
# 280     12908             692
# 514     28097            3357
# 89      18362            4019
# 340     17032            1018
# 250     16265            1861
# 537     24820            1144
# 386     21922            2922
# 616     15632             177
# 310     13762             316
# 192     13815            1537
# 569     20773             289
# 302     12225             369
# 162     12999            1476
# 596     17135             199
# 369     33193            6854
# 576     19734             214
# 144     15070            2519
# 399     14703            1285
# 90      14650            3114
# 168     13170            1567
# ...

# %%
z_train
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-9665543df857> in <module>
# ----> 1 z_train
#
# NameError: name 'z_train' is not defined

# %%
L_reg.predict([[679, 41]])

# %%
L_reg.score(x_test.values.reshape(-1,1), y_test.values, z_test.values)
